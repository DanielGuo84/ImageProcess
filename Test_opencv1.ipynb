# %% [markdown]
# 1. pip install opencv-contrib-python
# contrib模块包含一些非免费/专利算法

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
cv2.__version__
# Out:
# '4.1.0'

# %%
img = cv2.imread('C:\\Users\\Big data\\Pictures\\Saved Pictures\\2.jpeg')

# %%
# 寫入不同圖檔格式
cv2.imwrite('output.jpg', img)
cv2.imwrite('output.tiff', img)
# Out:
# True

# %%
# 設定 JPEG 圖片品質為 90（可用值為 0 ~ 100）
cv2.imwrite('output.jpg', img, [cv2.IMWRITE_JPEG_QUALITY, 90])
# 設定 PNG 壓縮層級為 5（可用值為 0 ~ 9）
cv2.imwrite('output.png', img, [cv2.IMWRITE_PNG_COMPRESSION, 5])
# Out:
# True

# %%
# 使用 OpenCV 讀取圖檔
img_bgr = cv2.imread('C:\\Users\\Big data\\Pictures\\Saved Pictures\\2.jpeg')
# 將 BGR 圖片轉為 RGB 圖片
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
# 使用 Matplotlib 顯示圖片
plt.imshow(img_rgb)
plt.show()

# %%
# 使用 OpenCV 讀取灰階圖檔
img_gray = cv2.imread('C:\\Users\\Big data\\Pictures\\Saved Pictures\\2.jpeg',cv2.IMREAD_GRAYSCALE)
# 使用 Matplotlib 顯示圖片
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
# 讀取圖檔
img = cv2.imread('C:\\Users\\Big data\\Pictures\\Saved Pictures\\2.jpeg')
# 裁切區域的 x 與 y 座標（左上角）
x = 100
y = 100
# 裁切區域的長度與寬度
w = 250
h = 150
# 裁切圖片
crop_img = img[y:y+h, x:x+w]
plt.imshow(crop_img)
plt.show()

# %% [markdown]
# pip install opencv-contrib-python

# %%
#將臉部進行辨識，然後將臉部數據另存為統一的格式。
import cv2

img = cv2.imread('C:\\Users\\Big data\\Anaconda3\\positive_images\\2.jpeg')
#人臉識別分類器
face_haar = cv2.CascadeClassifier("C:\\Users\\Big data\\Anaconda3\\Lib\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml")

# 把圖像轉為黑白圖像
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#檢測圖像中的所有臉
#人臉檢測，1.2和2分別為圖片縮放比例和需要檢測的有效點數
faces = face_haar.detectMultiScale(gray_img, scaleFactor = 1.3, minNeighbors = 5)
for face_x, face_y, face_w, face_h in faces:
    cv2.rectangle(img, (face_x, face_y), (face_x+face_w, face_y+face_h), (0,255,0), 2)
        
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-5067d9ff8a08> in <module>
#       7
#       8 # 把圖像轉為黑白圖像
# ----> 9 gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      10 #檢測圖像中的所有臉
#      11 #人臉檢測，1.2和2分別為圖片縮放比例和需要檢測的有效點數
#
# error: OpenCV(4.1.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
#ppt_智能超市
#取得照片作特徵值比對
face, ids = getImageAndLabels('C:\\Users\\Big data\\Anaconda3\\positive_images\\3.jpeg')
#把特徵值的部分轉為灰階並進行訓練
recognizer.train(faces, np.array(ids))

#找到訓練樣本中的臉
image = cv2.imread('C:\\Users\\Big data\\Anaconda3\\pictures\\3.jpeg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces = face_haar.detectMultiScale(gray_img, scaleFactor = 1.3, minNeighbors = 5)
#樣本上的臉做特徵分類
recognizer = cv2.face.LBPHFaceRecognizer_create()
detector = cv2.CascadeClassifier("haarcascade frontalface default.xml")
#建立模型存入指定目錄(需先自行建立trainer folder)
recognizer.write('trainer/trainer.yml')

#把訓練好的yml檔建立一個識別器物件,並把準備好的xml檔建出一個分類器
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('./trainer/trainer.yml')
cascadePath = "haarcascade frontalface default.xml"
faceCascade = cv2.CascadeClassifier(cascadePath)
#補捉影像上的人臉
image = cv2.imread('C:\\Users\\Big data\\Anaconda3\\positive_images\\1.jpeg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, scaleFactor = 1.2, minNeighbors = 5)

#框出人臉並用識別器辨別該人臉的id
cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 5)
id, confidence = recognizer.predict(gray[y:y+h, x:x+w])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ba27767fbb24> in <module>
#       1 #ppt_智能超市
#       2 #取得照片作特徵值比對
# ----> 3 face, ids = getImageAndLabels('C:\\Users\\Big data\\Anaconda3\\positive_images\\3.jpeg')
#       4 #把特徵值的部分轉為灰階並進行訓練
#       5 recognizer.train(faces, np.array(ids))
#
# NameError: name 'getImageAndLabels' is not defined

# %%
#ppt_智能超市
#人臉自動偵測測 & 自動拍照
cap = cv2.VideoCapture(0)
num = 0
while cap.isOpened():
    ok, frame = cap.read() #讀取一畫面數據
    if not ok:
        break
#人臉檢測
faceRects = classifier.detecMultiScale(grey, scaleFactor = 1.2, minNeighbors = 3, minSize(32, 32))

if len(faceRects) >0: #大於0則偵測到人臉
    time.sleep(2)
    for faceRects in faceRects:  #單獨框出每一張人臉
        x, y, w, h = faceRect
        #將當前畫面保存為圖片
        img_name = "%s/%d.jpg" % (path_name, num)
        #print(img_name)
        image = frame[y-10: y+h+10, x-10: x+w+10]
        cv2.imwrite(img_name, image, [int(cv2,IMWRITE_PNG_COMPRESSION), 9])
        
        num += 1
        if num > (catch_pic_num):  #如果超過最大保存數量則退出循環
            break
#連續截2張圖像, 存進image文件夾中, (("get face", 0, 1 [0,99 即是拍100張], "要存檔的路徑")
CatchPICFromVideo(("get face", 0, 1, "./images/0")
# Out:
#   File "<ipython-input-24-4857d73ca5ee>", line 26
#     CatchPICFromVideo(("get face", 0, 1, "./images/0")
#                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
# 人臉識別分類器, 使用opencv自帶的人臉分類器
faceCascade=cv2.CascadeClassifier(r'C:\python3.7\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml')
# 開啟攝像頭   默認筆記本的攝像頭是第0號攝像頭，如果有外置攝像頭，並向啟動就是1
cap = cv2.VideoCapture(0)
# 讀取攝像頭中的圖像，ok為是否讀取成功的判斷參數
ok, img = cap.read()
# 人臉檢測
faces = faceCascade.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5, minSize=(32, 32))
# 畫矩形  
cv2.rectangle(img, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)
#顯示視頻視窗  
cv2.imshow('video', img)
#獲取按鍵指令
k = cv2.waitKey(1)
#關閉攝像頭
cap.release()
#銷毀全部表單
cv2.destroyAllWindows()
# 轉為灰度圖片 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# 保存圖像    
cv2.imwrite(path, src)
#打開圖片，並轉化為灰度
PIL_img = Image.open(imagePath).convert('L')
 
import cv2
import os
import shutil
import numpy as np
from PIL import Image

def red(date):
    faces = cv2.CascadeClassifier(r"C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect\haarcascades\haarcascade_frontalface_default.xml")
    cap=cv2.VideoCapture(0)
    face_id=input("\n enter user id: ")
    count=0
    while True:
        ret, img = cap.read()
        if ret:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            face = faces.detectMultiScale(gray,1.05, 10,minSize=(32,32))
            for (x,y,w,h) in face:
                cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
                if h+w>=300:
                    new_img = cv2.resize(img[y:y + h, x:x + w], (92, 112))  # 調整圖像大小
                    count+=1
                    cv2.imwrite("ALLFace/User."+str(face_id)+"."+str(count)+".jpg",new_img)
                    cv2.imshow('image',img)
            k=cv2.waitKey(1)
            if k==27:
                break
            if count==500:
                break
    cap.release()
    cv2.destroyAllWindows()

def getImageAndLabels(path):
    detector = cv2.CascadeClassifier(
        r"C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect\haarcascades\haarcascade_frontalface_default.xml")
    imagePaths = [os.path.join(path, f) for f in os.listdir(path)]  # join函數的作用
    faceSamples = []
    ids = []
    for imagePath in imagePaths:
        PIL_img = Image.open(imagePath).convert('L')  # convert it to grayscale
        img_numpy = np.array(PIL_img, 'uint8')
        id = int(os.path.split(imagePath)[-1].split(".")[1])
        faces = detector.detectMultiScale(img_numpy)
        for (x, y, w, h) in faces:
            faceSamples.append(img_numpy[y:y + h, x: x + w])
            ids.append(id)
    return faceSamples, ids


def train(path):
    recohnizer=cv2.face.LBPHFaceRecognizer_create()
    faces,ids=getImageAndLabels(path)
    recohnizer.train(faces,np.array(ids))
    recohnizer.write(r'E:\01STUDY\20190701\work\deathopencv\train\trainer.yml')
    print("{0} faces trained.exiting program".format(len(np.unique(ids))))

def realize():
    recohnizer = cv2.face.LBPHFaceRecognizer_create()
    recohnizer.read(r'E:\01STUDY\20190701\work\deathopencv\train\trainer.yml')
    cascadePath=(r"C:\projects\opencv-python\opencv\modules\objdetect\src\cascadedetect\haarcascades\haarcascade_frontalface_default.xml")
    facaeCascade=cv2.CascadeClassifier(cascadePath)
    font=cv2.FONT_HERSHEY_SIMPLEX
    idnum=0
    name={1:"ymz"}
    cap=cv2.VideoCapture(0)
    minW=0.1*cap.get(3)
    minH=0.1*cap.get(4)
    while True:
        ret, img = cap.read()
        if ret:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            face = facaeCascade.detectMultiScale(gray,1.05, 10,minSize=(32,32))
            for (x,y,w,h) in face:
                cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
                idnum,confidence=recohnizer.predict(gray[y:y+h,x:x+w])
                print(idnum)
                if confidence<100 :#置信度大於50%
                    idnum=name[idnum]
                    confidence="{0}%".format(round(100-confidence))
                else:
                    idnum="unknown"
                    confidence="{0}%".format(round(100-confidence))
                cv2.putText(img,idnum,(x+5,y-5),font,1,(255,0,0),1)
                cv2.putText(img,str(confidence),(x+5,y+h-5),font,1,(0,0,0),1)
            cv2.imshow('camera',img)
            k=cv2.waitKey(10)
            if k==27:
                break
    cap.release()
    cv2.destroyAllWindows()


if __name__=='__main__':
    date2=r'E:\01STUDY\20190701\work\deathopencv\ALLface'
    #red(date2)
    #train(date2)
    realize()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-14ffb8ac9919> in <module>
#       6 ok, img = cap.read()
#       7 # 人臉檢測
# ----> 8 faces = faceCascade.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5, minSize=(32, 32))
#       9 # 畫矩形
#      10 cv2.rectangle(img, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)
#
# NameError: name 'gray' is not defined
